# %% [markdown]
# <div>
#     <h1 style = "font-size: 50px ">Data Visualization:</h1>
#     <p style="font-size:20px">Data visualization is a crucial process in machine learning (ML) that involves using graphical representations (e.g., charts, graphs, maps) to explore, understand, and communicate data patterns, trends, and model performance.
#     </p>
#
# </div>
# <ul class="KsbFXc U6u95" jscontroller="mPWODf" jsuid="RHTt9_1s" data-processed="true"><li jscontroller="vsuOFb" jsuid="RHTt9_1t" data-hveid="CAcQAA"><span class="T286Pc" data-sfc-cp="" jscontroller="fly6D" jsuid="RHTt9_1u"><strong class="Yjhzub" jscontroller="zYmgkd" jsuid="RHTt9_1v">Histograms and Density Plots:<!--Sv6Kpe[]--></strong> Show the distribution of a single numerical variable to understand its shape, spread, and central tendency.<!--Sv6Kpe[]--></span><!--Sv6Kpe[]--></li><li jscontroller="vsuOFb" jsuid="RHTt9_1w" data-hveid="CAcQAQ"><span class="T286Pc" data-sfc-cp="" jscontroller="fly6D" jsuid="RHTt9_1x"><strong class="Yjhzub" jscontroller="zYmgkd" jsuid="RHTt9_1y">Box and Whisker Plots:<!--Sv6Kpe[]--></strong> Summarize data distribution using quartiles and are excellent for identifying outliers.<!--Sv6Kpe[]--></span><!--Sv6Kpe[]--></li><li jscontroller="vsuOFb" jsuid="RHTt9_1z" data-hveid="CAcQAg"><span class="T286Pc" data-sfc-cp="" jscontroller="fly6D" jsuid="RHTt9_20"><strong class="Yjhzub" jscontroller="zYmgkd" jsuid="RHTt9_21">Scatter Plots and Pair Plots:<!--Sv6Kpe[]--></strong> Visualize the relationship between two or more variables, helping to spot correlations, clusters, or trends.<!--Sv6Kpe[]--></span><!--Sv6Kpe[]--></li><li jscontroller="vsuOFb" jsuid="RHTt9_22" data-hveid="CAcQAw"><span class="T286Pc" data-sfc-cp="" jscontroller="fly6D" jsuid="RHTt9_23"><strong class="Yjhzub" jscontroller="zYmgkd" jsuid="RHTt9_24">Bar Charts:<!--Sv6Kpe[]--></strong> Ideal for comparing quantities across different categories, often used to display feature importance or compare model performance metrics.<!--Sv6Kpe[]--></span><!--Sv6Kpe[]--></li><li jscontroller="vsuOFb" jsuid="RHTt9_25" data-hveid="CAcQBA"><span class="T286Pc" data-sfc-cp="" jscontroller="fly6D" jsuid="RHTt9_26"><strong class="Yjhzub" jscontroller="zYmgkd" jsuid="RHTt9_27">Heatmaps (Correlation Matrices):<!--Sv6Kpe[]--></strong> Use color intensity to represent values in a matrix format, clearly showing the correlation between multiple variables.<!--Sv6Kpe[]--></span><!--Sv6Kpe[]--></li><li jscontroller="vsuOFb" jsuid="RHTt9_28" data-hveid="CAcQBQ"><span class="T286Pc" data-sfc-cp="" jscontroller="fly6D" jsuid="RHTt9_29"><strong class="Yjhzub" jscontroller="zYmgkd" jsuid="RHTt9_2a">Line Charts (Learning Curves):<!--Sv6Kpe[]--></strong> Display trends over time or iterations, useful for tracking model accuracy or loss during training.<!--Sv6Kpe[]--></span><span jsuid="RHTt9_2b" class="uJ19be notranslate" jsaction="rcuQ6b:&amp;RHTt9_2b|npT2md" jscontroller="udAs2b" data-wiz-uids="RHTt9_2b,RHTt9_2c,RHTt9_2d"><span class="vKEkVd" data-animation-atomic="" data-wiz-attrbind="class=RHTt9_2b/TKHnVd;">&nbsp;<button jsuid="RHTt9_2d" tabindex="0" data-amic="true" data-icl-uuid="b85cd78b-28f0-4f93-a809-e719fb7e961e" aria-label="View related links" class="rBl3me" jsaction="click:&amp;RHTt9_2b|S9kKve;mouseenter:&amp;RHTt9_2b|sbHm2b;mouseleave:&amp;RHTt9_2b|Tx5Rb" data-wiz-attrbind="disabled=RHTt9_2b/C5gNJc;class=RHTt9_2b/UpSNec;" data-ved="2ahUKEwiS_czShsiRAxXqRaQEHdkgK1QQye0OegQIBxAG"><span class="wiMplc ofC0Ud"><svg style="margin-top: 3px;" fill="currentColor" width="12px" height="12px" focusable="false" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M3.9 12c0-1.71 1.39-3.1 3.1-3.1h4V7H7c-2.76 0-5 2.24-5 5s2.24 5 5 5h4v-1.9H7c-1.71 0-3.1-1.39-3.1-3.1zM8 13h8v-2H8v2zm9-6h-4v1.9h4c1.71 0 3.1 1.39 3.1 3.1s-1.39 3.1-3.1 3.1h-4V17h4c2.76 0 5-2.24 5-5s-2.24-5-5-5z"></path></svg></span></button></span><!--Sv6Kpe[[null,null,&quot;b85cd78b-28f0-4f93-a809-e719fb7e961e&quot;,null,null,1,0,&quot;&quot;,&quot;&quot;]]--></span><!--Sv6Kpe[]--></li><!--Sv6Kpe[]--></ul>
