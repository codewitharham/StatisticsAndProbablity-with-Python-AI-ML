# %%
import pandas as pd

# %%
dataPathUrl = "Data/toyota.csv"
Source = pd.read_csv("Data/toyota.csv") 
Source
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %%
Source
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %%
# The Pandas Treat the Table as DICTIONARY which has key Value Pair

# <identifier>[key<tablefield> ] --- gives all rows 

Source["model"]
# Out:
# 0                 GT86
# 1                 GT86
# 2                 GT86
# 3                 GT86
# 4                 GT86
#              ...
# 6733                IQ
# 6734     Urban Cruiser
# 6735     Urban Cruiser
# 6736     Urban Cruiser
# 6737     Urban Cruiser
# Name: model, Length: 6738, dtype: object

# %% [markdown]
# <h1><b>*DATA VISUALIZATION*</b></h1>

# %%
demoList = [-10,-2,3,10,12,16,18,-9,5,-5]

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(demoList)
plt.show()

# %%
# CREATE FIGURE:
plt.figure(figsize=(10,8))

# add a line renderer with legend and line thickness
plt.plot(demoList)

# making the figure readable--- very important from STAT desc
plt.title("First demo Plot")
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.grid()

plt.show()

# %% [markdown]
# <h1></b> SCATTER PLOT : </h1>

# %%
# CREATE FIGURE:
plt.figure(figsize=(10,10))

# add a line renderer with legend and line thickness
mileageDataList = Source["mileage"]
mileageDataListRange = range(mileageDataList.size)
plt.scatter(mileageDataListRange, mileageDataList, marker='x', s = 0.3)

# making the figure readable--- very important from STAT desc
plt.title("Mileage of Toyota's Car")
plt.xlabel("ID's Of Cars")
plt.ylabel("Mileage")
# plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # CREATE FIGURE:
# ----> 2 plt.figure(figsize=(10,10))
#       4 # add a line renderer with legend and line thickness
#       5 mileageDataList = Source["mileage"]
#
# NameError: name 'plt' is not defined
